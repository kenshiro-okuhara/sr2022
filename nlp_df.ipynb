# %%
from spacy import displacy
import spacy
from spacy import displacy
import pandas as pd

nlp = spacy.load('ja_ginza')

filename = "sample_2.csv"

#テキスト読み込み
df = pd.read_csv(filename, usecols=["現病歴"], encoding="shift-jis")

colors = {"COUNTRY":"#00cc00", "CITY":"#00cc00", "GPE_OTHER":"#00cc00","OCCASION_OTHER":"#00cc00",
      "LOCATION":"#00cc00", "LOCATION_OTHER":"#00cc00","DOMESTIC_REGION":"#00cc00","PROVINCE":"#00cc00",
      "STATION":"#00cc00", "CONTINENTAL_REGION":"#00cc00","THEATER":"#00cc00",

      "TIME":"#adff2f","DATE":"#adff2f","DAY_OF_WEEK":"#adff2f",
      "PERIOD_YEAR":"#adff2f", "PERIOD_MONTH":"#adff2f", "PERIOD_DAY":"#adff2f",

      "FLORA":"#adff99","FLORA_PART":"#adff99",
      "DISH":"#ffeb99","FOOD_OTHER":"#ffeb99",

      "AGE":"#3385ff","N_PERSON":"#3385ff","N_EVENT":"#3385ff","N_LOCATION_OTHER":"#3385ff","RANK":"#3385ff",
      "N_PRODUCT":"#3385ff","":"#3385ff","":"#3385ff","":"#3385ff","MEASUREMENT_OTHER":"#3385ff","PERCENT":"#3385ff",
      "N_ORGANIZATION":"#3385ff", "ORDINAL_NUMBER":"#3385ff", "N_FACILITY":"#3385ff","SPEED":"#3385ff",
      "PHONE_NUMBER":"#3385ff",

      "MONEY":"#ffff00",

      "COMPANY":"#99c2ff", "SCHOOL":"#99c2ff", "INTERNATIONAL_ORGANIZATION":"#99c2ff",
      "GOE_OTHER":"#99c2ff", "SHOW_ORGANIZATION":"#99c2ff","CORPORATION_OTHER":"#99c2ff",

      "CLOTHING":"#ff66a3",
      "PRODUCT_OTHER":"#ff66a3",

      "PERSON":"#c266ff",
      "POSITION_VOCATION":"#ebccff",

      "MUSIC":"#ff7f50", "MOVIE":"#ff7f50", "GAME":"#ff7f50", "SPORT":"#ff7f50", "BOOK":"#ff7f50", 
      "BROADCAST_PROGRAM":"#ff7f50", 

      "ANIMAL_DISEASE":"#cd5c5c"
      }

options = {"colors": colors}

n = 5

for i in range(n):
    text = nlp(df["現病歴"][i])
    displacy.render(text, style="ent", options=options, jupyter=True)

# for i in len(df):
#     text = df[i]
#     doc = nlp(text)
#     displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">現病歴：出生・発達は問題なし(出生時体重は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3300g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Weight</span>
# </mark>
# )．小学校の時，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     足
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# は速く，かけっこでは
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1-2位
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# であった．鉄棒は苦手ではあったものの逆上がりも習得した．町の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     柔道場
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sports_Facility</span>
# </mark>
# に通って
# <mark class="entity" style="background: #ff7f50; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     柔道
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sport</span>
# </mark>
# を習っていた．
# <mark class="entity" style="background: #00cc00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     中高一貫校
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Occasion_Other</span>
# </mark>
# に入学，中学校は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     生物部
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Organization_Other</span>
# </mark>
# ，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     高校
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nationality</span>
# </mark>
# は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     放送研究会
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Organization_Other</span>
# </mark>
# に所属．運動はあまりしなかったが，
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3年間
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Year</span>
# </mark>
#
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     朝
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
#
# <mark class="entity" style="background: #ff7f50; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     野球
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sport</span>
# </mark>
# をやっていた．学業成績は上位だった(
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     58人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# 中
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11位
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Rank</span>
# </mark>
# )．大学に入学してからも運動はしていなかったが，生活に不便を感じることはなかった．
# <mark class="entity" style="background: #ebccff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     社会人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position_Vocation</span>
# </mark>
# になり，商売を行っていた．配達などの肉体労働もあったが，不便は感じなかった．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# (
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     59歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# )の時に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     十二指腸
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# の
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     リンパ腫
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# と診断された．治療で寛解．このころから，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     足
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# をよくつるようになった．以降，症状は全くなく経過し，
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# の
# <mark class="entity" style="background: #00cc00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     江戸
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">City</span>
# </mark>
# 歩きの時には問題なかった(
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Year</span>
# </mark>
# に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1回
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
# 行っていた)．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018年8月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# ，
# <mark class="entity" style="background: #00cc00; padding: 0.45em 0.6e
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">現病歴：
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# （
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     47歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# ）
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# 、ボランティア（
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     糖尿病
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# に関する臨床研究）で血液検査を施行したところ、CKと
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     胆道
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# 系酵素の上昇を指摘された（
# <mark class="entity" style="background: #ff66a3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CK1190IU/L
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Product_Other</span>
# </mark>
# 、
# <mark class="entity" style="background: #ff66a3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Product_Other</span>
# </mark>
# 41IU/L、ALT33IU/L、
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     γ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Measurement_Other</span>
# </mark>
# -GTP
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     75IU/L
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Measurement_Other</span>
# </mark>
# ）。同時期、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ふくらはぎ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# が張って
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     かかと
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# を地面につけられず、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     つま先
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# 歩きをするようになった。
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     階段
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Facility_Part</span>
# </mark>
# をスムーズにあがれず、右上肢もあがらなくなった。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10月頃
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# から平地歩行や立ち上がりも困難さを自覚した。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# （
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     48歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# ）
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Year</span>
# </mark>
# 、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     左上肢
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# も挙上が難しくなり、洗濯物を取り込めなくなった。
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     四肢
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# に網状の
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     紫斑
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# が時々出現するようになった。体重が
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9kg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Weight</span>
# </mark>
# 減少した（
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009/468
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# kg→
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010/459
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# kg）。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# に
# <mark class="entity" style="background: #99c2ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A病院
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOE_Other</span>
# </mark>
# の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">現病歴：小学校から高校まで
# <mark class="entity" style="background: #ff7f50; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     野球
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sport</span>
# </mark>
# （右投げ右打ち、
# <mark class="entity" style="background: #ebccff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ピッチャー
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position_Vocation</span>
# </mark>
# ）をやっており、運動は得意な方だった。ここ数年野球を再開している。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1998年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# （
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     31歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# ）の
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     冬
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# 、出勤中に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     左手
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# がなんとなくだるく力が入りにくい事に気づいた。痛みや異常な感覚は認めなかった。料理の時にフライパンを
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     左手
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# で反そうとしたがうまくいかなかった。その後力の入りにくさはゆっくりと悪くなり、特に寒い季節に悪いと感じていた。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2003年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# （
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     36歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# ）12月ごろより
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     左親指
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# ・
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     示指
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# ・
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     中指
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# の先が「正座した後の感じ」のようにピリピリするようになったが、感覚は薄れていなかった。また、仕事（設計）のためパソコンに向かう時間が長く、
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     首
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# がこるようになるにつれ
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     左手
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# の力が入りにくくなりキーボードが打ちにくくなった。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2004年1月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     浦和福岡クリニック
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Pro_Sports_Organization</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     整形外科
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Academic</span>
# </mark>
# 受診、採血・頚部
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Ordinal_Number</span>
# </mark>
# ・頚部
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MRI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Doctrine_Method_Other</span>
# </mark>
# が行われたが異常は認められなかった。
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# （
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     37歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# ）には
# <mark class="entity" style="background: #99c2ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     東京厚生年金病院
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOE_Other</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     整形外科
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Academic</span>
# </mark>
# でも精査（頚部
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MRI・NCS・EMG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Doctrine_Method_Other</span>
# </mark>
# ）が行われた。結果、NCSでlt.ulnarnerveMCVで
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     手関節
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">現病歴：
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016年9月末頃
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# から下肢疲労感が徐々に強くなり
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Physical_Extent</span>
# </mark>
# も歩けなくなった．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10月頃
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# から右上肢を
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     肩
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# から上に持ち上げられなくなった．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11月末
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# に
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     一人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# で立ち上がれなくなり当科を受診し，近位筋筋力低下および
# <mark class="entity" style="background: #ff66a3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CK8,271IU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Product_Other</span>
# </mark>
# /lと異常高値を認めたため
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     筋炎
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# が疑われ入院した．先行感染は明らかでなかった．</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">現病歴：
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018年6月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# 某日（
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     第1病日
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Ordinal_Number</span>
# </mark>
# ）
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     午前中
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
# に
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     右下肢全体
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Product</span>
# </mark>
# ，特に右殿部から
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     大腿
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# 後面を中心に電気が走るような激痛が出現した．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     夕方
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
# ，歩行時に右足がつまずくようになったが何とか歩けた．右
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     下肢
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# の筋力が次第に低下して
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     夜
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
# には歩けなくなり，
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     第2病日
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Ordinal_Number</span>
# </mark>
# に救急外来を受診した．体温36.8°C，血圧
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     155/100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Organization</span>
# </mark>
# mmHg，また血液検査，単純
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     頭部MRI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Organization_Other</span>
# </mark>
# でも著変なく，
# <mark class="entity" style="background: #99c2ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     右Lasgue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GOE_Other</span>
# </mark>
# 徴候陽性から
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     腰椎椎間板ヘルニア
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# を疑われて緊急入院した．しかし，
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     腰椎MRI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# では
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     腰部脊柱管狭窄
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Doctrine_Method_Other</span>
# </mark>
# や
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     腹部大動脈
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# の異常はみられず，
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     第4病日
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# ，当科に紹介された．
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     両上肢
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# はまったく無症状で，
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     便通
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# 異常や
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     排尿障害
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# もなかった．また，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     数カ月以内
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
# に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ワクチン接種
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Doctrine_Method_Other</span>
# </mark>
# や感染症状，体重減少はなかった．</div></span>

# %%
# Out:
# 118
# 現病歴：2009年（47歳）7月、ボランティア（糖尿病に関する臨床研究）で血液検査を施行したところ、CKと胆道系酵素の上昇を指摘された（CK1190IU/L、AST41IU/L、ALT33IU/L、γ-GTP75IU/L）。同時期、ふくらはぎが張ってかかとを地面につけられず、つま先歩きをするようになった。階段をスムーズにあがれず、右上肢もあがらなくなった。10月頃から平地歩行や立ち上がりも困難さを自覚した。2010年（48歳）1月、左上肢も挙上が難しくなり、洗濯物を取り込めなくなった。四肢に網状の紫斑が時々出現するようになった。体重が9kg減少した（2009/468kg→2010/459kg）。2月にA病院の神経内科受診。B病院を紹介受診し、５月に精査入院した。「MMTは頸部前屈/後屈2、四肢近位3、四肢遠位4。肩外転は右90度、左70度。肘関節屈曲と足関節背屈でROM制限あり。腓腹筋に把握痛あり。つま先立ち可能だが踵立ち不可。片足立ち可。軽度waddlinggait。階段昇降は手すりを要する。四肢腱反射低下。」と所見記載あり、血液検査ではWBC9610/μL、CRP1.29mg/dl、CK2233IU/L、AST55IU/L、ALT30IU/Lであり、抗ミトコンドリアM2抗体陽性が判明した。呼吸機能はVC2.19L、%VC78.5%と低下していた。針筋電図で筋原性変化を認め、左上腕二頭筋から筋生検を施行した（所見は後述）。腹部エコーや腹部CTで特記すべき所見はなかったが、抗ミトコンドリア抗体陽性、IgM高値、慢性的に肝胆道系酵素が上昇している点から、筋生検の所見と併せて、無症候性原発性胆汁性肝硬変（asymptomaticPBC）に関連した多発筋炎の診断になった。ウルソ内服を開始し、胆道系酵素が改善傾向にあった。筋炎の治療目的に、C医療センターに入院。PSL50mg/dayを導入され、一人で臥位から起き上がることができるようになった。PSL30mg/dayまで漸減し、退院した。2011年（49歳）1月、両前腕が腫脹することがあった。2012年（50歳）でステロイドの内服を漸減終了。日常生活を問題なく行えていた。2017年（55歳）5月、坂を登るのがきつくなり、息切れがした。飲み込みづらさもあった。筋炎の再燃としてステロイド内服が再開となり、筋力は改善しCKも低下した。東京への転居をきっかけに、10月から帝京大学附属病院脳神経内科に転医した。2018年（56歳）2月、体幹部に皮膚硬化所見が出現し、右側腹部から生検施行。抗Scl-70抗体陰性であり限局性強皮症の診断になった。2019年（57歳）、プログラフが開始になった。ベッドがフラットだと息苦しくなるようになった。2020年（58歳）、１年間で体重が18kg減少した（58→40kg）。PSL5mg/day内服していたが、合併症予防のため中止した。7月、呼吸苦が出現し、帝京大学病院循環器内科に入院し、たこつぼ型心筋症の診断になった。１週間程度で退院したが、退院後すぐに疲れやすくなり、体動時に息切れが出現した。下痢が続き、四肢の浮腫が強くなった。筋力も低下し車椅子を使用するようになったが、階段昇降はなんとかできていた。固形物が飲み込みづらくなり、とろみを付けるようになった。CK値や外来でのMMTは著変がなかった。7月に帝京大学の耳鼻科受診。口腔咽頭に器質的異常を認めず、筋力低下に起因する嚥下障害と言われた。ろれつが回らず喋りづらくなり、唾も飲み込みづらくなった。9月に当科の嚥下外来初診。PSL5mgが開始となり、嚥下障害と構音障害が改善した。10月、評価目的に当科へ入院した。【既往歴】23歳頃：右大腿骨骨折、33歳頃：２型糖尿病（インスリン導入歴あり、網膜症で右眼レーザー治療後）、48歳：左硝子体出血（レーザー治療後）、高血圧症、心房細動、58歳：たこつぼ型心筋症
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">現病歴：出生・発達は問題なし(出生時体重は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3300g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Weight</span>
# </mark>
# )．小学校の時，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     足
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# は速く，かけっこでは
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1-2位
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# であった．鉄棒は苦手ではあったものの逆上がりも習得した．町の
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     柔道場
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sports_Facility</span>
# </mark>
# に通って
# <mark class="entity" style="background: #ff7f50; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     柔道
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sport</span>
# </mark>
# を習っていた．
# <mark class="entity" style="background: #00cc00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     中高一貫校
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Occasion_Other</span>
# </mark>
# に入学，中学校は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     生物部
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Organization_Other</span>
# </mark>
# ，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     高校
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Nationality</span>
# </mark>
# は
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     放送研究会
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Organization_Other</span>
# </mark>
# に所属．運動はあまりしなかったが，
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3年間
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Year</span>
# </mark>
#
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     朝
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Time</span>
# </mark>
#
# <mark class="entity" style="background: #ff7f50; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     野球
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sport</span>
# </mark>
# をやっていた．学業成績は上位だった(
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     58人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">N_Person</span>
# </mark>
# 中
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11位
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Rank</span>
# </mark>
# )．大学に入学してからも運動はしていなかったが，生活に不便を感じることはなかった．
# <mark class="entity" style="background: #ebccff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     社会人
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position_Vocation</span>
# </mark>
# になり，商売を行っていた．配達などの肉体労働もあったが，不便は感じなかった．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# (
# <mark class="entity" style="background: #3385ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     59歳
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# )の時に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     十二指腸
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# の
# <mark class="entity" style="background: #cd5c5c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     リンパ腫
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Disease</span>
# </mark>
# と診断された．治療で寛解．このころから，
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     足
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Animal_Part</span>
# </mark>
# をよくつるようになった．以降，症状は全くなく経過し，
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# の
# <mark class="entity" style="background: #00cc00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     江戸
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">City</span>
# </mark>
# 歩きの時には問題なかった(
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Period_Year</span>
# </mark>
# に
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1回
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
# 行っていた)．
# <mark class="entity" style="background: #adff2f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018年8月
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# ，
# <mark class="entity" style="background: #00cc00; padding: 0.45em 0.6e
